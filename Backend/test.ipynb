# %%
# %pip install -U typing_extensions pydantic pydantic-core openai langchain-openai
# Out:
# Requirement already satisfied: typing_extensions in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (4.15.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -treamlit (c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pydantic in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (2.12.5)
# Requirement already satisfied: pydantic-core in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (2.41.5)
# Requirement already satisfied: openai in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (2.16.0)
# Requirement already satisfied: langchain-openai in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (1.1.7)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.25.2)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.6 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-openai) (1.2.8)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.6.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (8.3.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.14.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.3)
# Requirement already satisfied: colorama in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.10.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.25.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\j rishi krishna\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.2.3)

# %%
from langchain_openai import ChatOpenAI
 
llm = ChatOpenAI(
    model="self-hosted",
    api_key="dummy",
    base_url="http://154.201.127.0:5000/v1"
)
 
llm.invoke("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(
#       4     model="self-hosted",
#       5     api_key="dummy",
#       6     base_url="http://154.201.127.0:5000/v1"
#       7 )
#       9 llm.invoke("What is the capital of France?")
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_openai\__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_openai\chat_models\azure.py:10
#       7 from collections.abc import AsyncIterator, Awaitable, Callable, Iterator
#       8 from typing import Any, Literal, TypeAlias, TypeVar
# ---> 10 import openai
#      11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\__init__.py:9
#       6 import typing as _t
#       7 from typing_extensions import override
# ----> 9 from . import types
#      10 from ._types import NOT_GIVEN, Omit, NoneType, NotGiven, Transport, ProxiesTypes, omit, not_given
#      11 from ._utils import file_from_path
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\types\batch.py:6
#       3 from typing import List, Optional
#       4 from typing_extensions import Literal
# ----> 6 from .._models import BaseModel
#       7 from .batch_error import BatchError
#       8 from .batch_usage import BatchUsage
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\openai\_models.py:38
#      21 from datetime import date, datetime
#      22 from typing_extensions import (
#      23     List,
#      24     Unpack,
#    (...)
#      35     runtime_checkable,
#      36 )
# ---> 38 import pydantic
#      39 from pydantic.fields import FieldInfo
#      41 from ._types import (
#      42     Body,
#      43     IncEx,
#    (...)
#      50     HttpxRequestFiles,
#      51 )
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\__init__.py:5
#       2 from typing import TYPE_CHECKING
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION, _ensure_pydantic_core_version
#       8 _ensure_pydantic_core_version()
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from pydantic.warnings import PydanticDeprecatedSince20
#       6 from .version import version_short
#       8 MOVED_IN_V2 = {
#       9     'pydantic.utils:version_info': 'pydantic.version:version_info',
#      10     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      15     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      16 }
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\warnings.py:5
#       1 """Pydantic-specific warnings."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from .version import version_short
#       7 __all__ = (
#       8     'PydanticDeprecatedSince20',
#       9     'PydanticDeprecatedSince26',
#    (...)
#      18     'TypedDictExtraConfigWarning',
#      19 )
#      22 class PydanticDeprecationWarning(DeprecationWarning):
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\version.py:7
#       3 from __future__ import annotations as _annotations
#       5 import sys
# ----> 7 from pydantic_core import __version__ as __pydantic_core_version__
#       9 __all__ = 'VERSION', 'version_info'
#      11 VERSION = '2.12.5'
#
# File c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic_core\__init__.py:6
#       3 import sys as _sys
#       4 from typing import Any as _Any
# ----> 6 from typing_extensions import Sentinel
#       8 from ._pydantic_core import (
#       9     ArgsKwargs,
#      10     MultiHostUrl,
#    (...)
#      29     to_jsonable_python,
#      30 )
#      31 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#
# ImportError: cannot import name 'Sentinel' from 'typing_extensions' (c:\Users\J RISHI KRISHNA\AppData\Local\Programs\Python\Python310\lib\site-packages\typing_extensions.py)

# %%
from langchain_openai import ChatOpenAI
 
llm = ChatOpenAI(
    model="self-hosted",
    api_key="dummy",
    base_url="http://154.201.127.0:5000/v1"
)

llm.invoke("What is the capital of France?")
